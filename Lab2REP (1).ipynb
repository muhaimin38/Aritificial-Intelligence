# %% [markdown]
# # lab2 REP

# %%
print("Abdul Muhaimin")
# Out:
# Abdul Muhaimin

# %% [markdown]
# # **Task 1:Lists**

# %%
numbers = [10, 31, 45, 34, 67, 89, 38, 98]
print('original List:', numbers)

print('Sum:', sum(numbers))
print('Max:', max(numbers))
print('Min:', min(numbers))

numbers.append(100)
numbers.remove(31)

print('Updated List:', numbers)

print('Accending:', )
# Out:
# original List: [10, 31, 45, 34, 67, 89, 38, 98]
# Sum: 412
# Max: 98
# Min: 10
# Updated List: [10, 45, 34, 67, 89, 38, 98, 100]

# %%
no = 1
result = 100
while (no < result):
  print('current no is: ', no)
  no = no+1

# %% [markdown]
# # **Task 2:Tuples**

# %%
fruits = ('apple', 'orange', 'bannana', 'cherry', 'mango')
print('Second element:', fruits[1])
print('Last element:', fruits[-1])

# Tuples are immutiable, so modification will give an error
# Convert tuple to list

fruit_list = list(fruits)
fruit_list[2] = 'grapes'
print('Modified List:', fruit_list)
# Out:
# Second element: orange
# Last element: mango
# Modified List: ['apple', 'orange', 'grapes', 'cherry', 'mango']

# %% [markdown]
# # **Task 3:Sets**

# %%
set_a = {1,2,3,4,5}
set_b = {4,5,6,7,8}

#Union, Intersection, Difference
print('Union:', set_a)

# %% [markdown]
# # **Task 4:Dictionaries**

# %%
students = {'Ali':85, 'Sara':90, 'Ahmed': 78, 'Omar': 100}
#Print keys and values
print('Key:', students.keys())
print('Values:', students.values())

#Update value
students['Ali'] = 95
print('Updated Dictionary:', students)

#Delete a key-value pair
del students['Ahmed']
print('After Deletion:', students)
# Out:
# Key: dict_keys(['Ali', 'Sara', 'Ahmed', 'Omar'])
# Values: dict_values([85, 90, 78, 100])
# Updated Dictionary: {'Ali': 95, 'Sara': 90, 'Ahmed': 78, 'Omar': 100}
# After Deletion: {'Ali': 95, 'Sara': 90, 'Omar': 100}
